# %%
import pyidd
print(pyidd)
# Out:
# <module 'pyidd' from '/home/masoud/projects/idd/pyidd/pyidd.py'>

# %%
import statsmodels.api as sm
data = sm.datasets.elnino.load_pandas().data.set_index('YEAR').values.ravel()

# %%
p = pyidd.PyIDD(verbose=1)

# %%
p.fit(data)
# Out:
# distribution: alpha_gen
# #SSE: 0.6851503588579635
# #params: (12.21805523547504, -4.061312511551051, 329.53131279939976)
# distribution: anglit_gen
# #SSE: 0.6744467874884568
# #params: (23.656556014417603, 7.137059902382464)
# distribution: arcsine_gen
# #SSE: 2.7190433944779757
# #params: (18.949275846267483, 10.290724153732517)
# distribution: argus_gen
# #SSE: 2.170646919526808
# #params: (1.1412211990007537e-05, 16.921018616724076, 12.324733540318107)
# distribution: beta_gen
# #SSE: 0.5466024412466157
# #params: (1.7370942638441165, 2.686199014557706, 18.91411832813299, 10.61964492300753)
# distribution: betaprime_gen
# #SSE: 0.691726943430887
# #params: (1069.3208846777802, 175.40686644261154, -4.269219362259777, 4.462067894153847)
# distribution: bradford_gen
# #SSE: 0.9064416858307986
# #params: (1.0803575936475398, 18.949999964741025, 10.290001249181362)
# distribution: burr_gen
# #SSE: 0.6786383309204036
# #params: (12.305141837507243, 8.878175746417924, -0.13599939602894942, 18.5969793250798)
# distribution: burr12_gen
# #SSE: 0.7732666548991906
# #params: (14.314088188218054, 1.6977940408334944, 0.8198948920984362, 23.40784078511023)
# distribution: cauchy_gen
# #SSE: 0.9812556560768217
# #params: (22.74246609503572, 1.621866779688143)
# distribution: chi_gen
# #SSE: 9.204969235372475
# #params: (0.4078803613886301, 18.949999999999996, 3.2421065180324087)
# distribution: chi2_gen
# #SSE: 0.6445312641733052
# #params: (11.016521585835578, 17.589764476785014, 0.4995095113757766)
# distribution: cosine_gen
# #SSE: 0.6426453515354711
# #params: (23.272749311593465, 1.9609545905821362)
# distribution: crystalball_gen
# #SSE: 0.7128926132479825
# #params: (1617.0062216837537, 24.416541747851397, 23.092618030640658, 2.2443758287130118)
# distribution: dgamma_gen
# #SSE: 0.6997458817000208
# #params: (1.9654277513278355, 23.069979283764873, 0.9848120914907972)
# distribution: dweibull_gen
# #SSE: 0.6343144515264605
# #params: (1.6822637541157985, 23.404281383793084, 2.180792134236973)
# distribution: erlang_gen
# #SSE: 0.6445315708468088
# #params: (5.508301382343174, 17.589747481007393, 0.9990146955196479)
# distribution: expon_gen
# #SSE: 1.2894724180316726
# #params: (18.95, 4.142622950819671)
# distribution: exponnorm_gen
# #SSE: 0.7125775170543239
# #params: (0.306268186999902, 22.435145967527447, 2.146759336942524)
# distribution: exponweib_gen
# #SSE: 0.5660056286011756
# #params: (0.29257280852089984, 4.520033480714275, 18.94233083990013, 6.923334720429665)
# distribution: exponpow_gen
# #SSE: 16.569899914988195
# #params: (0.2893742504625769, 18.949999999999996, 1.5825385630782187)
# distribution: f_gen
# #SSE: 0.6788418059103287
# #params: (2202.188134835066, 99.45801297957887, 7.675458795409135, 15.108789224108728)
# distribution: fatiguelife_gen
# #SSE: 0.6628995698888984
# #params: (0.24604966850128876, 13.76865995712852, 9.049956874338239)
# distribution: fisk_gen
# #SSE: 0.7295567229392348
# #params: (6.160938237186066, 14.579696108599537, 8.257454703799123)
# distribution: foldcauchy_gen
# #SSE: 0.870534308515151
# #params: (2.1873387046405424, 18.949999996377667, 1.6633768857952622)
# distribution: foldnorm_gen
# #SSE: 0.6710967516026043
# #params: (1.1477933304885823, 18.949999987957355, 3.210251628280031)
# distribution: frechet_r_gen
# #SSE: 10.684493683491873
# #params: (0.5780568152641371, 18.949999999999996, 1.2091011452364173)
# distribution: frechet_l_gen
# #SSE: 0.6761058518850264
# #params: (5.092620355726915, 32.808966998994734, 10.597659660158715)
# distribution: genlogistic_gen
# #SSE: 0.6648672246432402
# #params: (254.29916225548652, 11.289791150557978, 1.9348180769719208)
# distribution: gennorm_gen
# #SSE: 0.5462071742268216
# #params: (4.383601935463517, 23.299144426270487, 3.8499137613564454)
# distribution: genpareto_gen
# #SSE: 2.071213520176634
# #params: (-1.6540146774314168, -0.129743055502626, 48.577986086190776)
# distribution: genexpon_gen
# #SSE: 0.5950728983401345
# #params: (6.350246890758266e-08, 1.2475217319597367, 0.33816455980588733, 18.68523368196758, 1.956706123516529)
# distribution: genextreme_gen
# #SSE: 0.6761016409379399
# #params: (0.1963561009204678, 22.211281711672076, 2.0809807607435284)
# distribution: gausshyper_gen
# #SSE: 0.5488056676461284
# #params: (1.5814142259524835, 3.4740080197251113, 7.4553641570380424, -0.22311979671059268, 18.927968692935195, 10.860880341179644)
# distribution: gamma_gen
# #SSE: 0.6444915579860747
# #params: (5.506987453559015, 17.590111390531064, 0.9991994248469172)
# distribution: gengamma_gen
# #SSE: 0.5677768044658694
# #params: (0.25902534896761054, 5.04683928432061, 18.94272170843101, 7.574438102669336)
# distribution: genhalflogistic_gen
# #SSE: 1.948130007353176
# #params: (1.045588327403538, 17.507116722561314, 12.267765801678056)
# distribution: geninvgauss_gen
# #SSE: 0.6444180622622978
# #params: (5.532460666724141, 0.24201020357851438, 17.574689908420094, 0.12063073564274725)
# distribution: gilbrat_gen
# #SSE: 0.8765092606500711
# #params: (18.909116522680854, 3.4309151234166446)
# distribution: gompertz_gen
# #SSE: 0.6006578291635662
# #params: (0.24687462244240727, 18.949999999682255, 3.069729132370119)
# distribution: gumbel_r_gen
# #SSE: 0.663823387037593
# #params: (22.001363462951797, 1.9403082962240057)
# distribution: gumbel_l_gen
# #SSE: 0.7828414489726141
# #params: (24.23485554340609, 2.204993446360673)
# distribution: halfcauchy_gen
# #SSE: 1.1725943536486434
# #params: (18.949999996937372, 3.5948986526616125)
# distribution: halflogistic_gen
# #SSE: 0.937084122435937
# #params: (18.949999992885665, 2.8625198487812336)
# distribution: halfnorm_gen
# #SSE: 0.8720085620739614
# #params: (18.94999999959861, 4.711704813006049)
# distribution: halfgennorm_gen
# #SSE: 2.2701481376554606
# #params: (0.5717811431159501, 18.94999999498237, 1.2113686059814976)
# distribution: hypsecant_gen
# #SSE: 0.8308036268440058
# #params: (22.96834196981595, 1.6488126066494395)
# distribution: invgamma_gen
# #SSE: 0.6907253903596691
# #params: (143.373989420596, -3.565115228269578, 3795.167943018183)
# distribution: invgauss_gen
# #SSE: 0.6636526205931262
# #params: (0.059027080893424566, 13.592938959322538, 160.87272559177998)
# distribution: invweibull_gen
# #SSE: 0.6692307936885897
# #params: (11.568717332754694, -0.0718021119789447, 21.985235314326204)
# distribution: johnsonsb_gen
# #SSE: 0.5357835973697368
# #params: (0.48180802182650617, 0.9835826571292925, 18.689276660398363, 10.958573456318526)
# distribution: johnsonsu_gen
# #SSE: 0.6736678272522669
# #params: (-12.710732373712887, 4.676046375620052, 12.598045932364606, 1.3600556879490648)
# distribution: kappa4_gen
# #SSE: 1.0887651104503502
# #params: (1.0726622898674103, 1.0577467350897733, 18.157505425784844, 11.722472472267187)
# distribution: kappa3_gen
# #SSE: 0.6141680774814157
# #params: (15.201828674972806, 18.949999919764256, 6.594188476800447)
# distribution: ksone_gen
# #SSE: 1.0313730573609141
# #params: (1.0248040750273568, 18.94999938136794, 10.290000853626971)
# distribution: kstwo_gen
# distribution: kstwobign_gen
# #SSE: 0.631488654092411
# #params: (15.198593405759205, 9.033493897346725)
# distribution: laplace_gen
# #SSE: 1.047617669960862
# #params: (22.855, 1.9299180327868852)
# distribution: levy_gen
# #SSE: 1.298562392259723
# #params: (18.852475136238077, 2.556893602539218)
# distribution: levy_l_gen
# #SSE: 1.8513831930157256
# #params: (29.38387587362506, 4.899593805743201)
# distribution: logistic_gen
# #SSE: 0.775860537326326
# #params: (23.020962849607272, 1.3492010473602272)
# distribution: loggamma_gen
# #SSE: 0.7094135537933209
# #params: (1562.3399064023515, -634.9520373927658, 89.48676895481145)
# distribution: loglaplace_gen
# #SSE: 1.0474456038006266
# #params: (12.04912820522847, -0.14792922482292836, 22.997929968123216)
# distribution: lognorm_gen
# #SSE: 0.6722908989315721
# #params: (0.21431564497493877, 12.516330563641468, 10.33830410030749)
# distribution: reciprocal_gen
# #SSE: 2.92023078009737
# #params: (0.9015482215897133, 1.6009849280375819, 0.0021890907748951093, 7.134297062689321e-31)
# distribution: lomax_gen
# #SSE: 1.3251930200608186
# #params: (486.8363091523702, 18.949227553286825, 1966.7773310253406)
# distribution: maxwell_gen
# #SSE: 0.6529535704522818
# #params: (17.898002244503132, 3.267082804634997)
# distribution: mielke_gen
# #SSE: nan
# #params: (72645.20025120646, 65.1632408607473, -104.50307903803525, 113.57889324654809)
# distribution: moyal_gen
# #SSE: 0.6607977729800336
# #params: (21.588735181121507, 1.2388813923145827)
# distribution: nakagami_gen
# #SSE: 0.5987402377961277
# #params: (0.9152569379493534, 18.88300831081137, 4.77050936172974)
# distribution: ncx2_gen
# #SSE: 0.8471589514169949
# #params: (2.9198605317440425, 2.5964793321916723e-08, 18.94601322995809, 1.3559500152668325)
# distribution: ncf_gen
# #SSE: 0.6932811502207092
# #params: (351.2567137567131, 688.3585497530191, 24.88393251519988, -1.0502602818986193, 22.474319344922478)
# distribution: nct_gen
# #SSE: 0.6871581875365447
# #params: (62.99618434710257, 30.501035209372176, -0.26041781555144483, 0.7563779286240817)
# distribution: norm_gen
# #SSE: 0.7128961490763479
# #params: (23.09262295081967, 2.2443681683984593)
# distribution: norminvgauss_gen
# #SSE: 0.6926161961407318
# #params: (746.8111070264952, 734.4046422059864, -2.552888908112492, 4.733791751517916)
# distribution: pareto_gen
# #SSE: 1.5027429769254992
# #params: (5.150009257465317, 0.10005714198099414, 18.849942857647974)
# distribution: pearson3_gen
# #SSE: 0.6445270708116693
# #params: (0.8521718119533641, 23.09261505012909, 2.3446788635259015)
# distribution: powerlaw_gen
# #SSE: 1.0711332968862197
# #params: (1.0662989528768636, 18.949114117119365, 10.290886477279205)
# distribution: powerlognorm_gen
# #SSE: 0.6388678732382955
# #params: (0.03965838962201002, 0.0397752442846768, 6.743758852563877, 12.858974883371795)
# distribution: powernorm_gen
# #SSE: nan
# #params: (9.146546107714347e-05, 18.78960956544347, 0.03282728325101622)
# distribution: rdist_gen
# #SSE: 0.6380276132408647
# #params: (6.842193428191575, 23.27330515822387, 6.2197872705156465)
# distribution: rayleigh_gen
# #SSE: 0.6125842711039828
# #params: (18.78028485829876, 3.4375768877150503)
# distribution: rice_gen
# #SSE: 0.6203220735350076
# #params: (0.9979359563995316, 18.720089514267563, 2.8395884580854327)
# distribution: recipinvgauss_gen
# #SSE: 0.6622216114001298
# #params: (0.06414249018709783, 13.948874954141639, 0.5511504374626657)
# distribution: semicircular_gen
# #SSE: 0.7922368193158187
# #params: (24.041990671465896, 5.205591269336804)
# distribution: skew_norm_gen
# #SSE: 0.6141331659256212
# #params: (5.3460209143242565, 19.994636981045335, 3.825527954997657)
# distribution: t_gen
# #SSE: 0.7129036673785077
# #params: (8080308.044104673, 23.0924844274104, 2.24430094398013)
# distribution: trapz_gen
# #SSE: 1.8982825733534947
# #params: (1.0, 1.0, 17.921, 12.347999999999999)
# distribution: triang_gen
# #SSE: 0.5506488516226017
# #params: (0.2085681555283213, 18.804789053103917, 10.525149473908202)
# distribution: truncexpon_gen
# #SSE: 0.8712637356494695
# #params: (0.9112114507629423, 18.949998887262396, 11.29266319418706)
# distribution: truncnorm_gen
# #SSE: 2.92023078009737
# #params: (0.9015482215897133, 1.6009849280375819, 0.0021890907748951093, 7.134297062689321e-31)
# distribution: tukeylambda_gen
# #SSE: 0.6331160518702647
# #params: (0.31462587583070956, 23.285066925644976, 1.9391316753032386)
# distribution: uniform_gen
# #SSE: 1.0313730573609012
# #params: (18.95, 10.29)
# distribution: vonmises_gen
# #SSE: 4.782634751506022e+53
# #params: (0.06514209082159045, 23.544322300201458, 3.239707867296754e-27)
# distribution: vonmises_gen
# #SSE: 0.7853890111386589
# #params: (1.0953702748205951, 23.052835468198104, 1.9694356390643786)
# distribution: wald_gen
# #SSE: 0.844193950287685
# #params: (18.70646707027371, 5.2912959476347865)
# distribution: weibull_min_gen
# #SSE: 10.684493683491873
# #params: (0.5780568152641371, 18.949999999999996, 1.2091011452364173)
# distribution: weibull_max_gen
# #SSE: 0.6761058518850264
# #params: (5.092620355726915, 32.808966998994734, 10.597659660158715)
# distribution: wrapcauchy_gen
# #SSE: nan
# #params: (1.0, 17.921, 1.9652452372987235)

# %%
p.plot(top=10)
# Out:
# /home/masoud/anaconda3/lib/python3.7/site-packages/pandas/plotting/_matplotlib/hist.py:54: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.
#   n, bins, patches = ax.hist(y, bins=bins, bottom=bottom, **kwds)

# %%
p.get_distributions()
# Out:
# [('johnsonsb_gen',
#   {'SSE': 0.5357835973697368,
#    'params': (0.48180802182650617,
#     0.9835826571292925,
#     18.689276660398363,
#     10.958573456318526)}),
#  ('gennorm_gen',
#   {'SSE': 0.5462071742268216,
#    'params': (4.383601935463517, 23.299144426270487, 3.8499137613564454)}),
#  ('beta_gen',
#   {'SSE': 0.5466024412466157,
#    'params': (1.7370942638441165,
#     2.686199014557706,
#     18.91411832813299,
#     10.61964492300753)}),
#  ('gausshyper_gen',
#   {'SSE': 0.5488056676461284,
#    'params': (1.5814142259524835,
#     3.4740080197251113,
#     7.4553641570380424,
#     -0.22311979671059268,
#     18.927968692935195,
#     10.860880341179644)}),
#  ('triang_gen',
#   {'SSE': 0.5506488516226017,
#    'params': (0.2085681555283213, 18.804789053103917, 10.525149473908202)}),
#  ('exponweib_gen',
#   {'SSE': 0.5660056286011756,
#    'params': (0.29257280852089984,
#     4.520033480714275,
#     18.94233083990013,
#     6.923334720429665)}),
#  ('gengamma_gen',
#   {'SSE': 0.5677768044658694,
#    'params': (0.25902534896761054,
#     5.04683928432061,
#     18.94272170843101,
#     7.574438102669336)}),
#  ('genexpon_gen',
#   {'SSE': 0.5950728983401345,
#    'params': (6.350246890758266e-08,
#     1.2475217319597367,
#     0.33816455980588733,
#     18.68523368196758,
#     1.956706123516529)}),
#  ('nakagami_gen',
#   {'SSE': 0.5987402377961277,
#    'params': (0.9152569379493534, 18.88300831081137, 4.77050936172974)}),
#  ('gompertz_gen',
#   {'SSE': 0.6006578291635662,
#    'params': (0.24687462244240727, 18.949999999682255, 3.069729132370119)}),
#  ('rayleigh_gen',
#   {'SSE': 0.6125842711039828,
#    'params': (18.78028485829876, 3.4375768877150503)}),
#  ('skew_norm_gen',
#   {'SSE': 0.6141331659256212,
#    'params': (5.3460209143242565, 19.994636981045335, 3.825527954997657)}),
#  ('kappa3_gen',
#   {'SSE': 0.6141680774814157,
#    'params': (15.201828674972806, 18.949999919764256, 6.594188476800447)}),
#  ('rice_gen',
#   {'SSE': 0.6203220735350076,
#    'params': (0.9979359563995316, 18.720089514267563, 2.8395884580854327)}),
#  ('kstwobign_gen',
#   {'SSE': 0.631488654092411,
#    'params': (15.198593405759205, 9.033493897346725)}),
#  ('tukeylambda_gen',
#   {'SSE': 0.6331160518702647,
#    'params': (0.31462587583070956, 23.285066925644976, 1.9391316753032386)}),
#  ('dweibull_gen',
#   {'SSE': 0.6343144515264605,
#    'params': (1.6822637541157985, 23.404281383793084, 2.180792134236973)}),
#  ('rdist_gen',
#   {'SSE': 0.6380276132408647,
#    'params': (6.842193428191575, 23.27330515822387, 6.2197872705156465)}),
#  ('powerlognorm_gen',
#   {'SSE': 0.6388678732382955,
#    'params': (0.03965838962201002,
#     0.0397752442846768,
#     6.743758852563877,
#     12.858974883371795)}),
#  ('cosine_gen',
#   {'SSE': 0.6426453515354711,
#    'params': (23.272749311593465, 1.9609545905821362)}),
#  ('geninvgauss_gen',
#   {'SSE': 0.6444180622622978,
#    'params': (5.532460666724141,
#     0.24201020357851438,
#     17.574689908420094,
#     0.12063073564274725)}),
#  ('gamma_gen',
#   {'SSE': 0.6444915579860747,
#    'params': (5.506987453559015, 17.590111390531064, 0.9991994248469172)}),
#  ('pearson3_gen',
#   {'SSE': 0.6445270708116693,
#    'params': (0.8521718119533641, 23.09261505012909, 2.3446788635259015)}),
#  ('chi2_gen',
#   {'SSE': 0.6445312641733052,
#    'params': (11.016521585835578, 17.589764476785014, 0.4995095113757766)}),
#  ('erlang_gen',
#   {'SSE': 0.6445315708468088,
#    'params': (5.508301382343174, 17.589747481007393, 0.9990146955196479)}),
#  ('maxwell_gen',
#   {'SSE': 0.6529535704522818,
#    'params': (17.898002244503132, 3.267082804634997)}),
#  ('moyal_gen',
#   {'SSE': 0.6607977729800336,
#    'params': (21.588735181121507, 1.2388813923145827)}),
#  ('recipinvgauss_gen',
#   {'SSE': 0.6622216114001298,
#    'params': (0.06414249018709783, 13.948874954141639, 0.5511504374626657)}),
#  ('fatiguelife_gen',
#   {'SSE': 0.6628995698888984,
#    'params': (0.24604966850128876, 13.76865995712852, 9.049956874338239)}),
#  ('invgauss_gen',
#   {'SSE': 0.6636526205931262,
#    'params': (0.059027080893424566, 13.592938959322538, 160.87272559177998)}),
#  ('gumbel_r_gen',
#   {'SSE': 0.663823387037593,
#    'params': (22.001363462951797, 1.9403082962240057)}),
#  ('genlogistic_gen',
#   {'SSE': 0.6648672246432402,
#    'params': (254.29916225548652, 11.289791150557978, 1.9348180769719208)}),
#  ('invweibull_gen',
#   {'SSE': 0.6692307936885897,
#    'params': (11.568717332754694, -0.0718021119789447, 21.985235314326204)}),
#  ('foldnorm_gen',
#   {'SSE': 0.6710967516026043,
#    'params': (1.1477933304885823, 18.949999987957355, 3.210251628280031)}),
#  ('lognorm_gen',
#   {'SSE': 0.6722908989315721,
#    'params': (0.21431564497493877, 12.516330563641468, 10.33830410030749)}),
#  ('johnsonsu_gen',
#   {'SSE': 0.6736678272522669,
#    'params': (-12.710732373712887,
#     4.676046375620052,
#     12.598045932364606,
#     1.3600556879490648)}),
#  ('anglit_gen',
#   {'SSE': 0.6744467874884568,
#    'params': (23.656556014417603, 7.137059902382464)}),
#  ('genextreme_gen',
#   {'SSE': 0.6761016409379399,
#    'params': (0.1963561009204678, 22.211281711672076, 2.0809807607435284)}),
#  ('frechet_l_gen',
#   {'SSE': 0.6761058518850264,
#    'params': (5.092620355726915, 32.808966998994734, 10.597659660158715)}),
#  ('weibull_max_gen',
#   {'SSE': 0.6761058518850264,
#    'params': (5.092620355726915, 32.808966998994734, 10.597659660158715)}),
#  ('burr_gen',
#   {'SSE': 0.6786383309204036,
#    'params': (12.305141837507243,
#     8.878175746417924,
#     -0.13599939602894942,
#     18.5969793250798)}),
#  ('f_gen',
#   {'SSE': 0.6788418059103287,
#    'params': (2202.188134835066,
#     99.45801297957887,
#     7.675458795409135,
#     15.108789224108728)}),
#  ('alpha_gen',
#   {'SSE': 0.6851503588579635,
#    'params': (12.21805523547504, -4.061312511551051, 329.53131279939976)}),
#  ('nct_gen',
#   {'SSE': 0.6871581875365447,
#    'params': (62.99618434710257,
#     30.501035209372176,
#     -0.26041781555144483,
#     0.7563779286240817)}),
#  ('invgamma_gen',
#   {'SSE': 0.6907253903596691,
#    'params': (143.373989420596, -3.565115228269578, 3795.167943018183)}),
#  ('betaprime_gen',
#   {'SSE': 0.691726943430887,
#    'params': (1069.3208846777802,
#     175.40686644261154,
#     -4.269219362259777,
#     4.462067894153847)}),
#  ('norminvgauss_gen',
#   {'SSE': 0.6926161961407318,
#    'params': (746.8111070264952,
#     734.4046422059864,
#     -2.552888908112492,
#     4.733791751517916)}),
#  ('ncf_gen',
#   {'SSE': 0.6932811502207092,
#    'params': (351.2567137567131,
#     688.3585497530191,
#     24.88393251519988,
#     -1.0502602818986193,
#     22.474319344922478)}),
#  ('dgamma_gen',
#   {'SSE': 0.6997458817000208,
#    'params': (1.9654277513278355, 23.069979283764873, 0.9848120914907972)}),
#  ('loggamma_gen',
#   {'SSE': 0.7094135537933209,
#    'params': (1562.3399064023515, -634.9520373927658, 89.48676895481145)}),
#  ('exponnorm_gen',
#   {'SSE': 0.7125775170543239,
#    'params': (0.306268186999902, 22.435145967527447, 2.146759336942524)}),
#  ('crystalball_gen',
#   {'SSE': 0.7128926132479825,
#    'params': (1617.0062216837537,
#     24.416541747851397,
#     23.092618030640658,
#     2.2443758287130118)}),
#  ('norm_gen',
#   {'SSE': 0.7128961490763479,
#    'params': (23.09262295081967, 2.2443681683984593)}),
#  ('t_gen',
#   {'SSE': 0.7129036673785077,
#    'params': (8080308.044104673, 23.0924844274104, 2.24430094398013)}),
#  ('fisk_gen',
#   {'SSE': 0.7295567229392348,
#    'params': (6.160938237186066, 14.579696108599537, 8.257454703799123)}),
#  ('burr12_gen',
#   {'SSE': 0.7732666548991906,
#    'params': (14.314088188218054,
#     1.6977940408334944,
#     0.8198948920984362,
#     23.40784078511023)}),
#  ('logistic_gen',
#   {'SSE': 0.775860537326326,
#    'params': (23.020962849607272, 1.3492010473602272)}),
#  ('gumbel_l_gen',
#   {'SSE': 0.7828414489726141,
#    'params': (24.23485554340609, 2.204993446360673)}),
#  ('vonmises_gen',
#   {'SSE': 0.7853890111386589,
#    'params': (1.0953702748205951, 23.052835468198104, 1.9694356390643786)}),
#  ('semicircular_gen',
#   {'SSE': 0.7922368193158187,
#    'params': (24.041990671465896, 5.205591269336804)}),
#  ('hypsecant_gen',
#   {'SSE': 0.8308036268440058,
#    'params': (22.96834196981595, 1.6488126066494395)}),
#  ('wald_gen',
#   {'SSE': 0.844193950287685,
#    'params': (18.70646707027371, 5.2912959476347865)}),
#  ('ncx2_gen',
#   {'SSE': 0.8471589514169949,
#    'params': (2.9198605317440425,
#     2.5964793321916723e-08,
#     18.94601322995809,
#     1.3559500152668325)}),
#  ('foldcauchy_gen',
#   {'SSE': 0.870534308515151,
#    'params': (2.1873387046405424, 18.949999996377667, 1.6633768857952622)}),
#  ('truncexpon_gen',
#   {'SSE': 0.8712637356494695,
#    'params': (0.9112114507629423, 18.949998887262396, 11.29266319418706)}),
#  ('halfnorm_gen',
#   {'SSE': 0.8720085620739614,
#    'params': (18.94999999959861, 4.711704813006049)}),
#  ('gilbrat_gen',
#   {'SSE': 0.8765092606500711,
#    'params': (18.909116522680854, 3.4309151234166446)}),
#  ('bradford_gen',
#   {'SSE': 0.9064416858307986,
#    'params': (1.0803575936475398, 18.949999964741025, 10.290001249181362)}),
#  ('halflogistic_gen',
#   {'SSE': 0.937084122435937,
#    'params': (18.949999992885665, 2.8625198487812336)}),
#  ('cauchy_gen',
#   {'SSE': 0.9812556560768217,
#    'params': (22.74246609503572, 1.621866779688143)}),
#  ('uniform_gen', {'SSE': 1.0313730573609012, 'params': (18.95, 10.29)}),
#  ('ksone_gen',
#   {'SSE': 1.0313730573609141,
#    'params': (1.0248040750273568, 18.94999938136794, 10.290000853626971)}),
#  ('loglaplace_gen',
#   {'SSE': 1.0474456038006266,
#    'params': (12.04912820522847, -0.14792922482292836, 22.997929968123216)}),
#  ('laplace_gen',
#   {'SSE': 1.047617669960862, 'params': (22.855, 1.9299180327868852)}),
#  ('powerlaw_gen',
#   {'SSE': 1.0711332968862197,
#    'params': (1.0662989528768636, 18.949114117119365, 10.290886477279205)}),
#  ('kappa4_gen',
#   {'SSE': 1.0887651104503502,
#    'params': (1.0726622898674103,
#     1.0577467350897733,
#     18.157505425784844,
#     11.722472472267187)}),
#  ('halfcauchy_gen',
#   {'SSE': 1.1725943536486434,
#    'params': (18.949999996937372, 3.5948986526616125)}),
#  ('expon_gen',
#   {'SSE': 1.2894724180316726, 'params': (18.95, 4.142622950819671)}),
#  ('levy_gen',
#   {'SSE': 1.298562392259723,
#    'params': (18.852475136238077, 2.556893602539218)}),
#  ('lomax_gen',
#   {'SSE': 1.3251930200608186,
#    'params': (486.8363091523702, 18.949227553286825, 1966.7773310253406)}),
#  ('pareto_gen',
#   {'SSE': 1.5027429769254992,
#    'params': (5.150009257465317, 0.10005714198099414, 18.849942857647974)}),
#  ('levy_l_gen',
#   {'SSE': 1.8513831930157256,
#    'params': (29.38387587362506, 4.899593805743201)}),
#  ('reciprocal_gen',
#   {'SSE': 2.92023078009737,
#    'params': (0.9015482215897133,
#     1.6009849280375819,
#     0.0021890907748951093,
#     7.134297062689321e-31)}),
#  ('mielke_gen',
#   {'SSE': nan,
#    'params': (72645.20025120646,
#     65.1632408607473,
#     -104.50307903803525,
#     113.57889324654809)}),
#  ('powernorm_gen',
#   {'SSE': nan,
#    'params': (9.146546107714347e-05, 18.78960956544347, 0.03282728325101622)}),
#  ('trapz_gen',
#   {'SSE': 1.8982825733534947,
#    'params': (1.0, 1.0, 17.921, 12.347999999999999)}),
#  ('genhalflogistic_gen',
#   {'SSE': 1.948130007353176,
#    'params': (1.045588327403538, 17.507116722561314, 12.267765801678056)}),
#  ('genpareto_gen',
#   {'SSE': 2.071213520176634,
#    'params': (-1.6540146774314168, -0.129743055502626, 48.577986086190776)}),
#  ('argus_gen',
#   {'SSE': 2.170646919526808,
#    'params': (1.1412211990007537e-05,
#     16.921018616724076,
#     12.324733540318107)}),
#  ('halfgennorm_gen',
#   {'SSE': 2.2701481376554606,
#    'params': (0.5717811431159501, 18.94999999498237, 1.2113686059814976)}),
#  ('arcsine_gen',
#   {'SSE': 2.7190433944779757,
#    'params': (18.949275846267483, 10.290724153732517)}),
#  ('truncnorm_gen',
#   {'SSE': 2.92023078009737,
#    'params': (0.9015482215897133,
#     1.6009849280375819,
#     0.0021890907748951093,
#     7.134297062689321e-31)}),
#  ('chi_gen',
#   {'SSE': 9.204969235372475,
#    'params': (0.4078803613886301, 18.949999999999996, 3.2421065180324087)}),
#  ('frechet_r_gen',
#   {'SSE': 10.684493683491873,
#    'params': (0.5780568152641371, 18.949999999999996, 1.2091011452364173)}),
#  ('weibull_min_gen',
#   {'SSE': 10.684493683491873,
#    'params': (0.5780568152641371, 18.949999999999996, 1.2091011452364173)}),
#  ('exponpow_gen',
#   {'SSE': 16.569899914988195,
#    'params': (0.2893742504625769, 18.949999999999996, 1.5825385630782187)}),
#  ('wrapcauchy_gen', {'SSE': nan, 'params': (1.0, 17.921, 1.9652452372987235)})]
